# %%
import os
import sparknlp_jsl


spark = sparknlp_jsl.start(
    license_id = os.getenv("JSL_LICENSE_ID", ""),
    license_secret = os.getenv("JSL_LICENSE_SECRET", ""),
    gpu = True,
    verbose = True
)
